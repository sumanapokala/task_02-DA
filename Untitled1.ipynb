# %% [markdown]
# <a href="https://colab.research.google.com/github/sumanapokala/task_02-DA/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv("tested.csv")
print("Shape of dataset:", df.shape)

print(df.head())


print(df.describe())

print(df.isnull().sum())

cat_cols = df.select_dtypes(include=["object"]).columns
for col in cat_cols:
    print(f"\nValue counts for {col}:")
    print(df[col].value_counts(dropna=False))

plt.figure(figsize=(10,5))
plt.imshow(df.isnull(), aspect="auto", cmap="viridis")
plt.title("Missing values (yellow = missing)")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()


num_cols = df.select_dtypes(include=[np.number]).columns
for col in num_cols:
    plt.hist(df[col].dropna(), bins=20)
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

for col in num_cols:
    plt.boxplot(df[col].dropna(), vert=False)
    plt.title(f"Boxplot of {col}")
    plt.show()

corr = df[num_cols].corr()

print(corr)

plt.imshow(corr, cmap="coolwarm")
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns, rotation=90)
plt.yticks(range(len(corr)), corr.columns)
plt.title("Correlation Heatmap")
plt.show()


print(df.groupby("Sex")["Age"].mean())

print(df[num_cols].skew())

for col in num_cols:
    data = df[col].dropna()
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    lower, upper = Q1 - 1.5*IQR, Q3 + 1.5*IQR
    outliers = data[(data < lower) | (data > upper)]
    print(f"{col}: {len(outliers)} outliers found")
# Out:
# Shape of dataset: (418, 12)
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S
# ...
